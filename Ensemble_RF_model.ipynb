# %% [markdown]
# # The Price is Right
#
# Today we build a more complex solution for estimating prices of goods.
#
# 1. Day 2.0 notebook: create a RAG database with our 400,000 training data
# 2. Day 2.1 notebook: visualize in 2D
# 3. Day 2.2 notebook: visualize in 3D
# 4. Day 2.3 notebook: build and test a RAG pipeline with GPT-4o-mini
# 5. Day 2.4 notebook: (a) bring back our Random Forest pricer (b) Create a Ensemble pricer that allows contributions from all the pricers
#
# Phew! That's a lot to get through in one day!
#
# ## PLEASE NOTE:
#
# We already have a very powerful product estimator with our proprietary, fine-tuned LLM. Most people would be very satisfied with that! The main reason we're adding these extra steps is to deepen your expertise with RAG and with Agentic workflows.
#
# ## Finishing off with Random Forests & Ensemble

# %%
# imports

import os
import re
import math
import json
from tqdm import tqdm
import random
from dotenv import load_dotenv
from huggingface_hub import login
import numpy as np
import pickle
from openai import OpenAI
from sentence_transformers import SentenceTransformer
from datasets import load_dataset
import chromadb
from items import Item
from testing import Tester
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
# CONSTANTS

QUESTION = "How much does this cost to the nearest dollar?\n\n"
DB = "products_vectorstore"

# %%
# environment

load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN', 'your-key-if-not-using-env')

# %%
# Log in to HuggingFace

hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# Another import after Logging in to Hugging Face - thank you Trung N.!

from items import Item

# %%
# Load in the test pickle file:

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')

# %%
result = collection.get(include=['embeddings', 'documents', 'metadatas'])
vectors = np.array(result['embeddings'])
documents = result['documents']
prices = [metadata['price'] for metadata in result['metadatas']]

# %% [markdown]
# # Random Forest
#
# We will now train a Random Forest model.
#
# Can you spot the difference from what we did in Week 6? In week 6 we used the word2vec model to form vectors; this time we'll use the vectors we already have in Chroma, from the SentenceTransformer model.

# %%
# This next line takes an hour on my M1 Mac!

rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(vectors, prices)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
# Save the model to a file

joblib.dump(rf_model, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']

# %%
# Load it back in again

rf_model = joblib.load('random_forest_model.pkl')

# %%
from agents.specialist_agent import SpecialistAgent
from agents.frontier_agent import FrontierAgent
from agents.random_forest_agent import RandomForestAgent

# %%
specialist = SpecialistAgent()
frontier = FrontierAgent(collection)
random_forest = RandomForestAgent()

# %%
def description(item):
    return item.prompt.split("to the nearest dollar?\n\n")[1].split("\n\nPrice is $")[0]

# %%
def rf(item):
    return random_forest.price(description(item))

# %%
Tester.test(rf, test)
# Out:
# 1: Guess: $276.64 Truth: $374.41 Error: $97.77 SLE: 0.09 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $202.10 Truth: $225.11 Error: $23.01 SLE: 0.01 Item: Motorcraft YB3125 Fan Clutch
# 215: Guess: $614.58 Truth: $399.99 Error: $214.59 SLE: 0.18 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $235.72 Truth: $599.00 Error: $363.28 SLE: 0.87 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $268.25 Truth: $105.99 Error: $162.26 SLE: 0.85 Item: Barbie Top Model Doll
# 218: Guess: $310.76 Truth: $689.00 Error: $378.24 SLE: 0.63 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $227.81 Truth: $404.99 Error: $177.18 SLE: 0.33 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $232.41 Truth: $207.76 Error: $24.65 SLE: 0.01 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $207.93 Truth: $171.82 Error: $36.11 SLE: 0.04 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $265.29 Truth: $293.24 Error: $27.95 SLE: 0.01 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $225.77 Truth: $374.95 Error: $149.18 SLE: 0.26 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $211.27 Truth: $111.99 Error: $99.28 SLE: 0.40 Item: SBU 3 Layer All Weather Mini Van Car Cov...
# 225: Guess: $116.94 Truth: $42.99 Error: $73.95 SLE: 0.97 Item: 2 Pack Outdoor Brochure Holder Advertisi...
# 226: Guess: $169.81 Truth: $116.71 Error: $53.10 SLE: 0.14 Item: Monroe Shocks & Struts Quick-Strut 17158...
# 227: Guess: $191.30 Truth: $118.61 Error: $72.69 SLE: 0.23 Item: Elements of Design Magellan EB235AL Thre...
# 228: Guess: $235.62 Truth: $147.12 Error: $88.50 SLE: 0.22 Item: GM Genuine Parts 15-62961 Air Conditioni...
# 229: Guess: $208.49 Truth: $119.99 Error: $88.50 SLE: 0.30 Item: Baseus 17-in-1 USB C Docking Station to ...
# 230: Guess: $164.98 Truth: $369.98 Error: $205.00 SLE: 0.65 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $251.79 Truth: $315.55 Error: $63.76 SLE: 0.05 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $324.28 Truth: $190.99 Error: $133.29 SLE: 0.28 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $231.94 Truth: $155.00 Error: $76.94 SLE: 0.16 Item: Bluetooth X6BT Card Reader Writer Encode...
# 234: Guess: $296.02 Truth: $349.99 Error: $53.97 SLE: 0.03 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $255.44 Truth: $249.99 Error: $5.45 SLE: 0.00 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $232.14 Truth: $42.99 Error: $189.15 SLE: 2.78 Item: PIT66 Front Bumper Turn Signal Lights, C...
# 237: Guess: $52.91 Truth: $17.99 Error: $34.92 SLE: 1.09 Item: Caseology Bumpy Compatible with Google P...
# 238: Guess: $246.72 Truth: $425.00 Error: $178.28 SLE: 0.29 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $305.20 Truth: $249.99 Error: $55.21 SLE: 0.04 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $203.96 Truth: $138.23 Error: $65.73 SLE: 0.15 Item: Schmidt Spiele - Manhattan
# 241: Guess: $271.00 Truth: $414.99 Error: $143.99 SLE: 0.18 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $208.41 Truth: $168.28 Error: $40.13 SLE: 0.05 Item: Hoshizaki FM116A Fan Motor Kit 1
# 243: Guess: $198.03 Truth: $199.99 Error: $1.96 SLE: 0.00 Item: BAINUO Antler Chandelier Lighting,6 Ligh...
# 244: Guess: $229.31 Truth: $126.70 Error: $102.61 SLE: 0.35 Item: DNA MOTORING HL-OH-FEXP06-SM-AM Smoke Le...
# 245: Guess: $209.00 Truth: $5.91 Error: $203.09 SLE: 11.66 Item: Wera Stainless 3840/1 TS 2.5mm Hex Inser...
# 246: Guess: $239.31 Truth: $193.06 Error: $46.25 SLE: 0.05 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $323.97 Truth: $249.99 Error: $73.98 SLE: 0.07 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $207.26 Truth: $64.12 Error: $143.14 SLE: 1.35 Item: Other Harmonica (Suzuki-2Timer24- A)
# 249: Guess: $254.10 Truth: $114.99 Error: $139.11 SLE: 0.62 Item: Harley Air Filter Venturi Intake Air Cle...
# 250: Guess: $363.05 Truth: $926.00 Error: $562.95 SLE: 0.87 Item: Elite Screens Edge Free Ambient Light Re...

# %%
product = "Quadcast HyperX condenser mic for high quality audio for podcasting"

# %%
print(specialist.price(product))
print(frontier.price(product))
print(random_forest.price(product))

# %%
specialists = []
frontiers = []
random_forests = []
prices = []
for item in tqdm(test[1000:1250]):
    text = description(item)
    specialists.append(specialist.price(text))
    frontiers.append(frontier.price(text))
    random_forests.append(random_forest.price(text))
    prices.append(item.price)

# %%
mins = [min(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
maxes = [max(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]

X = pd.DataFrame({
    'Specialist': specialists,
    'Frontier': frontiers,
    'RandomForest': random_forests,
    'Min': mins,
    'Max': maxes,
})

# Convert y to a Series
y = pd.Series(prices)

# %%
# Train a Linear Regression
np.random.seed(42)

lr = LinearRegression()
lr.fit(X, y)

feature_columns = X.columns.tolist()

for feature, coef in zip(feature_columns, lr.coef_):
    print(f"{feature}: {coef:.2f}")
print(f"Intercept={lr.intercept_:.2f}")

# %%
joblib.dump(lr, 'ensemble_model.pkl')

# %%
from agents.ensemble_agent import EnsembleAgent
ensemble = EnsembleAgent(collection)

# %%
ensemble.price(product)

# %%
def ensemble_pricer(item):
    return max(0,ensemble.price(description(item)))

# %%
Tester.test(ensemble_pricer, test)

# %% [markdown]
# # WHAT A DAY!
#
# We got so much done - a Fronter RAG pipeline, a Random Forest model using transformer-based encodings, and an Ensemble model.
#
# You can do better, for sure!
#
# Tweak this, and try adding components into the ensemble, to beat my performance.
